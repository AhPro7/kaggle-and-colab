# %% [markdown]
# <a href="https://colab.research.google.com/github/AhPro7/kaggle-and-colab/blob/main/Data_from_kaggle_Ahmed_Haytham_way.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Drive in first  
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # how to get you API
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1_you wil find it in Account tab
# ## 2_Click in creat new API token
# ## 3_save in drive for later as i do 😪
# ## 4_put API folder path in the code ⬇

# %%
# kaggle api folder no need for drive but i save

import os

os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/kaggle_api"   # folder path

# %% [markdown]
# # make a folder for data to save it in it

# %%
# make a folder for data and go to that folder

# %mkdir /content/data
# %cd /content/data

#back to content
#%cd /content/

# to know the path use
#! pwd
# Out:
# /content/data

# %% [markdown]
# # finally dowload dataset
# ## 1_Download it using its comand like ⬇
# ## 2_unzip it
# ## 3_use it

# %% [markdown]
# # how to get command of dataset
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1_ go to dataset
# ## 2_ click in three dots then copy API command
# ## 3_put in code down like ↙

# %%
# dataset API
# !kaggle datasets download -d ahmedhaytham/car-detection
# Out:
# ...
#  24% 9.00M/38.1M [00:00<00:00, 77.3MB/s]
# 100% 38.1M/38.1M [00:00<00:00, 182MB/s]

# %% [markdown]
# # unzip data

# %%
# path of dowmloaded zipped data
! unzip /content/data/car-detection.zip
# Out:
# Archive:  /content/data/car-detection.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#   inflating: test/images/00dea1edf14f09ab_jpg.rf.3f17c8790a68659d03b1939a59ccda80.jpg
#   inflating: test/images/00dea1edf14f09ab_jpg.rf.KJ730oDTFPdXdJxvSLnX.jpg
#   inflating: test/images/00e481ea1a520175_jpg.rf.6e6a8b3b45c9a11d106958f88ff714ea.jpg
#   inflating: test/images/00e481ea1a520175_jpg.rf.MV6sZ8QCFwFeMYaI2tHm.jpg
#   inflating: test/images/08c8b73e0c2e296e_jpg.rf.7IkYAamjZhnwsoXSrwKt.jpg
#   inflating: test/images/08c8b73e0c2e296e_jpg.rf.effa65856584463c08848031cab357b9.jpg
#   inflating: test/images/10c26c6598677a1f_jpg.rf.USCbBYVcUICkLhuq07Lw.jpg
#   inflating: test/images/10c26c6598677a1f_jpg.rf.f72b2b91e750909f68fffeee777e9350.jpg
#   inflating: test/images/1ef77c61856d3b4b_jpg.rf.HZMSiUVx3WUcMIooJMZX.jpg
#   inflating: test/images/1ef77c61856d3b4b_jpg.rf.a528f50763101224fad39907062c5026.jpg
# ...

# %% [markdown]
# # most important thing pls follow me 👉👈
#
#
# [Linked in](https://www.linkedin.com/in/ahmed-haytham/)
#
# [Kaggle](https://www.kaggle.com/ahmedhaytham)
#
# [Git hub](https://github.com/AhPro7)
#
# [Twitter](https://twitter.com/Ahmed_Haytham7)
